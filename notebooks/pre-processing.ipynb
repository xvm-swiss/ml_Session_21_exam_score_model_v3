# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv( '../data/feature eng data/feature_eng_data.csv' )

# %% [markdown]
# # Encoding Categorical Columns

# %% [markdown]
# ### * Encoding ordinal columns using Label Encoding

# %%
df.sample()
# Out:
#      gender            course  study_hours  class_attendance internet_access  \
# 2411   male  Bachelor of Arts         0.55              73.1             yes
#
#       sleep_hours sleep_quality   study_method facility_rating  \
# 2411          7.5          poor  online videos          medium
#
#      exam_difficulty  exam_score  course_diff
# 2411            easy        34.8            1

# %% [markdown]
# ### 1) columns to label encode :
#  'sleep_quality', 'facility_rating', 'exam_difficulty'

# %%
df['exam_difficulty'].unique()
# Out:
# array(['hard', 'moderate', 'easy'], dtype=object)

# %%
def encode_sleep_quality( df ) :
    df['sleep_quality'] = df['sleep_quality'].map({
        'poor' : 0, 'average' : 1, 'good' : 2
    })
    return df
    
df = encode_sleep_quality( df )

# %%
def encode_facility_rating( df ) :
    df['facility_rating'] = df['facility_rating'].map({
        'low' : 0, 'medium' : 1, 'high' : 2
    })
    return df
    
df = encode_facility_rating( df )

# %%
def encode_exam_difficulty( df ) :
    df['exam_difficulty'] = df['exam_difficulty'].map({
        'easy' : 0, 'moderate' : 1, 'hard' : 2
    })
    return df
    
df = encode_exam_difficulty( df )

# %%
df.sample()
# Out:
#      gender                             course  study_hours  class_attendance  \
# 5000  other  Bachelor of Computer Applications          1.1              46.3
#
#      internet_access  sleep_hours  sleep_quality study_method  \
# 5000              no          4.5              0        mixed
#
#       facility_rating  exam_difficulty  exam_score  course_diff
# 5000                0                1        37.2            4

# %%
df.shape
# Out:
# (20000, 12)

# %%
df
# Out:
#        gender                               course  study_hours  \
# 0        male                              Diploma         2.78
# 1       other    Bachelor of Computer Applications         3.37
# 2        male                  Bachelor of Science         7.88
# 3       other                              Diploma         0.67
# 4      female                              Diploma         0.89
# ...       ...                                  ...          ...
# 19995   other  Bachelor of Business Administration         6.50
# 19996    male                 Bachelor of Commerce         3.71
# 19997   other                              Diploma         7.88
# 19998    male  Bachelor of Business Administration         4.60
# 19999    male                  Bachelor of Science         7.50
#
#        class_attendance internet_access  sleep_hours  sleep_quality  \
# 0                  92.9             yes          7.4              0
# 1                  64.8             yes          4.6              1
# 2                  76.8             yes          8.5              0
# 3                  48.4             yes          5.8              1
# 4                  71.6             yes          9.8              0
# ...                 ...             ...          ...            ...
# 19995              71.3             yes          5.0              2
# 19996              41.6              no          5.9              1
# 19997              68.2             yes          4.6              0
# 19998              76.3              no          6.1              2
# 19999              47.9             yes          7.5              0
#
#         study_method  facility_rating  exam_difficulty  exam_score  \
# 0           coaching                0                2        58.9
# 1      online videos                1                1        54.8
# 2           coaching                2                1        90.3
# 3      online videos                0                1        29.7
# 4           coaching                0                1        43.7
# ...              ...              ...              ...         ...
# 19995     self-study                0                0        86.5
# 19996       coaching                1                1        60.9
# 19997    group study                0                0        64.5
# 19998     self-study                1                1        79.0
# 19999       coaching                1                1        71.0
#
#        course_diff
# 0                0
# 1                4
# 2                5
# 3                0
# 4                0
# ...            ...
# 19995            3
# 19996            2
# 19997            0
# 19998            3
# 19999            5
#
# [20000 rows x 12 columns]

# %%
df.to_csv( '../data/preprocessed data/pre-processed_data.csv', index = False )
